# %%
pip install huggingface_hub

huggingface-cli download nvidia/Nemotron-Mini-4B-Instruct --local-dir ./nemotron-mini-4b
# Out:
#   Cell In[1], line 3
#     huggingface-cli download nvidia/Nemotron-Mini-4B-Instruct --local-dir ./nemotron-mini-4b
#                                                   ^
# SyntaxError: invalid decimal literal

# %%
import os

# Clear the corporate proxy settings causing the connection failure
for var in ["http_proxy", "https_proxy", "HTTP_PROXY", "HTTPS_PROXY"]:
    if var in os.environ:
        del os.environ[var]

# Run the download using the modern syntax noted in your warning
from huggingface_hub import snapshot_download
snapshot_download(repo_id="nvidia/Nemotron-Mini-4B-Instruct", local_dir="./nemotron-mini-4b")
# Out:
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# nemo/nemotron-mini-4b-instruct.nemo:   0%|          | 0.00/8.39G [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/8.38G [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/646 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# (…)idia-community-model-license-aug2024.pdf: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/18.1M [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.55M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# '/Users/s0n0611/Documents/GitHub/SLM_PAPER/nemotron-mini-4b'

# %%
downloaded_path='/Users/s0n0611/Documents/GitHub/SLM_PAPER/nemotron-mini-4b'

print("\n🎉 Success!")
print(f"Model weights downloaded locally to: {downloaded_path}")
print("Directory contents:")
print(os.listdir(downloaded_path))
# Out:
# 🎉 Success!
# Model weights downloaded locally to: /Users/s0n0611/Documents/GitHub/SLM_PAPER/nemotron-mini-4b
# Directory contents:
# ['LICENSE', 'tokenizer_config.json', 'special_tokens_map.json', 'nemo', 'config.json', 'tokenizer.json', 'tokenizer.model', 'README.md', 'nvidia-community-model-license-aug2024.pdf', '.gitattributes', 'pytorch_model.bin', '.cache']

# %%
import os
from huggingface_hub import snapshot_download

# Clear corporate proxy settings to bypass resolution issues
for var in ["http_proxy", "https_proxy", "HTTP_PROXY", "HTTPS_PROXY"]:
    if var in os.environ:
        del os.environ[var]

# ----------------- CHOOSE YOUR MODEL HERE -----------------
# Option A: Microsoft Phi-3.5 Mini (3.8B - Top-tier reasoning SLM)
repo_id = "microsoft/Phi-3.5-mini-instruct"
local_dir = "./phi-3.5-mini"

# Option B: Meta Llama 3.2 (3B - Highly capable multilingual SLM)
# NOTE: Llama 3.2 is gated. Run !huggingface-cli login first.
# repo_id = "meta-llama/Llama-3.2-3B-Instruct"
# local_dir = "./llama-3.2-3b"

# Option C: Google Gemma 2 (2B - Exceptionally fast and lightweight)
# repo_id = "google/gemma-2-2b-it"
# local_dir = "./gemma-2-2b"
# ----------------------------------------------------------

print(f"Starting download for {repo_id}...")

downloaded_path = snapshot_download(
    repo_id=repo_id, 
    local_dir=local_dir,
    max_workers=4  # Downloads files in parallel
)

print("\n🎉 Success!")
print(f"Model weights downloaded locally to: {downloaded_path}")
print("Directory contents:")
print(os.listdir(downloaded_path))
# Out:
# Starting download for microsoft/Phi-3.5-mini-instruct...
# Fetching 20 files:   0%|          | 0/20 [00:00<?, ?it/s]
# LICENSE: 0.00B [00:00, ?B/s]
# CODE_OF_CONDUCT.md:   0%|          | 0.00/453 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# NOTICE.md: 0.00B [00:00, ?B/s]
# SECURITY.md: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_phi3.py: 0.00B [00:00, ?B/s]
# data_summary_card.md: 0.00B [00:00, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# modeling_phi3.py: 0.00B [00:00, ?B/s]
# sample_finetune.py: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...
